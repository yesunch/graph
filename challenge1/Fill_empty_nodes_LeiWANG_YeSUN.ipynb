# %%
import networkx as nx
# https://networkx.github.io/documentation/stable/reference/index.html
import matplotlib.pyplot as plt
from matplotlib import pylab
import numpy as np
import pandas as pd
from collections import Counter

# %% [markdown]
# # Which nodes' profile do we have to fill?

# %%
# Sub-problem: fill the profiles of 'empty' nodes
df_empty = pd.read_csv('./challenge1/empty.csv', sep='\t', header='infer')

# %%
df_empty.shape
# Out:
# (475, 1)

# %%
# Get a list from a Series
empty = df_empty['name'].drop_duplicates().tolist()
len(empty)
# Out:
# 475

# %% [markdown]
# # Profil data understanding

# %%
# We use pandas dataframes to load attributes
# Nodes are characterized by a list of colleges, a list of employers, a list of location
# The order means nothing. Nothing allow us to determine the current employer...
df_e = pd.read_csv('./challenge1/employer_with_60percent_of_nodes_remoded.csv', sep='\t', header='infer')
df_e.head()
# Out:
#     name                                           employer
# 0  U1313                                discovery education
# 1  U1313                                    ctb mcgraw-hill
# 2  U1313  university of charleston university of south c...
# 3  U1313             south carolina department of education
# 4  U1313                        chesapeake va and sumter sc

# %%
len(df_e[['name']])
# Out:
# 923

# %%
# How many users have 1 and more declared employers?
len(df_e[['name']].drop_duplicates())
# Out:
# 297

# %%
# load the graph
# The graph is an extraction from LinkedIn Social Network
G = nx.read_gexf("./challenge1/mediumLinkedin.gexf")
print("%d nodes have no employer attributes among the %d users in the graph" % (G.number_of_nodes()-len(df_e[['name']].drop_duplicates()), G.number_of_nodes()))
# Out:
# 514 nodes have no employer attributes among the 811 users in the graph

# %%
# How many employers / user?
df_e.groupby('name').count().describe()
# Out:
#          employer
# count  297.000000
# mean     3.107744
# std      1.976682
# min      1.000000
# 25%      1.000000
# 50%      3.000000
# 75%      4.000000
# max     13.000000

# %%
df_e['employer'].value_counts()
# Out:
# university of illinois at urbana-champaign                                       76
# microsoft                                                                        15
# google                                                                           15
# measured progress                                                                 5
# university of texas at austin                                                     5
# amazon                                                                            5
# university of illinois at chicago                                                 5
# oracle                                                                            4
# ets                                                                               4
# state farm insurance                                                              4
# microsoft research asia                                                           4
# educational testing service                                                       4
# apple                                                                             3
# goldman sachs                                                                     3
# illinois state university                                                         3
# ultimate software                                                                 3
# university of michigan                                                            3
# ibm                                                                               3
# morgan stanley                                                                    3
# hewlett-packard laboratories                                                      3
# shanghai jiao tong university                                                     3
# university of waterloo                                                            3
# bangladesh university of engineering &amp; technology                             3
# argonne national laboratory                                                       3
# boston consulting group                                                           2
# university of chicago                                                             2
# pricewaterhousecoopers                                                            2
# university of delaware                                                            2
# chicago public schools                                                            2
# center for educational testing and evaluation                                     2
#                                                                                  ..
# benjamin an and co. p.c.                                                          1
# university of virginia                                                            1
# siemens healthcare                                                                1
# inventiv health                                                                   1
# state university of new york at buffalo                                           1
# smarter balanced assessment consortium                                            1
# self                                                                              1
# toyota technical center                                                           1
# resolutions employment assistant program                                          1
# umass donahue institute                                                           1
# fudan university                                                                  1
# intered                                                                           1
# wayfair                                                                           1
# t-mobile                                                                          1
# bloomberg                                                                         1
# coordinated science lab                                                           1
# act                                                                               1
# chitralada palace school                                                          1
# brock university                                                                  1
# american eagle outfitters                                                         1
# university of pittsburgh school of information science                            1
# shell oil company                                                                 1
# niche mobile                                                                      1
# mckinsey &amp; company                                                            1
# office of community college research and leadership at university of illinois     1
# luster software                                                                   1
# hcs lab university of florida                                                     1
# state farm research and development center                                        1
# alternative spring break                                                          1
# jingyi futures co. ltd                                                            1
# Name: employer, Length: 723, dtype: int64

# %%
# Boolean row selection by values in a column
df_e.loc[df_e['employer'].isin(['google','google inc']),:].head()
# Out:
#        name employer
# 30    U3895   google
# 126  U15289   google
# 136  U24080   google
# 145  U24046   google
# 161   U7151   google

# %%
new = df_e.loc[df_e['employer'].isin(['google','google inc']),:]
print(new)
# Out:
#        name employer
# 30    U3895   google
# 126  U15289   google
# 136  U24080   google
# 145  U24046   google
# 161   U7151   google
# 172  U27661   google
# 179  U24154   google
# 229   U8699   google
# 314   U2761   google
# 451   U2631   google
# 720   U8721   google
# 742  U14131   google
# 771   U4568   google
# 831  U27494   google
# 860  U27758   google

# %% [markdown]
# # Exploration of the graph : relational data understanding, focus on homophily

# %%
# networkx short summary of information for the graph g
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 811
# Number of edges: 1597
# Average degree:   3.9383

# %% [markdown]
# ### Homophily understanding
# Test here the homophily in the graph for each attribute

# %%
for n in G.nodes(): # Loop through every node, in our data "n" will be the name of the person
    print(n, G.node[n]) # Access every node by its name, and then by the attribute "birth_year"
# Out:
# U27476 {'label': 'U27476'}
# U4665 {'label': 'U4665'}
# U1313 {'label': 'U1313'}
# U8804 {'label': 'U8804'}
# U14078 {'label': 'U14078'}
# U9628 {'label': 'U9628'}
# U9721 {'label': 'U9721'}
# U2649 {'label': 'U2649'}
# U27759 {'label': 'U27759'}
# U7310 {'label': 'U7310'}
# U22859 {'label': 'U22859'}
# U1417 {'label': 'U1417'}
# U25611 {'label': 'U25611'}
# U24095 {'label': 'U24095'}
# U3895 {'label': 'U3895'}
# U13005 {'label': 'U13005'}
# U2620 {'label': 'U2620'}
# U5976 {'label': 'U5976'}
# U4249 {'label': 'U4249'}
# U9140 {'label': 'U9140'}
# U16112 {'label': 'U16112'}
# U27776 {'label': 'U27776'}
# U27708 {'label': 'U27708'}
# U15284 {'label': 'U15284'}
# U24549 {'label': 'U24549'}
# U18514 {'label': 'U18514'}
# U15272 {'label': 'U15272'}
# U3933 {'label': 'U3933'}
# U15946 {'label': 'U15946'}
# U25630 {'label': 'U25630'}
# U25632 {'label': 'U25632'}
# U22031 {'label': 'U22031'}
# U11562 {'label': 'U11562'}
# U22071 {'label': 'U22071'}
# U15292 {'label': 'U15292'}
# U7912 {'label': 'U7912'}
# U22018 {'label': 'U22018'}
# U18925 {'label': 'U18925'}
# U7136 {'label': 'U7136'}
# U14498 {'label': 'U14498'}
# U21990 {'label': 'U21990'}
# U3927 {'label': 'U3927'}
# U1381 {'label': 'U1381'}
# U22087 {'label': 'U22087'}
# U27804 {'label': 'U27804'}
# U24252 {'label': 'U24252'}
# U7355 {'label': 'U7355'}
# U12969 {'label': 'U12969'}
# U2180 {'label': 'U2180'}
# U11815 {'label': 'U11815'}
# U4447 {'label': 'U4447'}
# U27679 {'label': 'U27679'}
# U27582 {'label': 'U27582'}
# U27464 {'label': 'U27464'}
# U8029 {'label': 'U8029'}
# U1075 {'label': 'U1075'}
# U24259 {'label': 'U24259'}
# U18564 {'label': 'U18564'}
# U27283 {'label': 'U27283'}
# U11575 {'label': 'U11575'}
# U14507 {'label': 'U14507'}
# U27477 {'label': 'U27477'}
# U25619 {'label': 'U25619'}
# U2661 {'label': 'U2661'}
# U24143 {'label': 'U24143'}
# U8000 {'label': 'U8000'}
# U22015 {'label': 'U22015'}
# U24152 {'label': 'U24152'}
# U11591 {'label': 'U11591'}
# U27585 {'label': 'U27585'}
# U27498 {'label': 'U27498'}
# U9663 {'label': 'U9663'}
# U14520 {'label': 'U14520'}
# U1441 {'label': 'U1441'}
# U2714 {'label': 'U2714'}
# U8051 {'label': 'U8051'}
# U27300 {'label': 'U27300'}
# U9149 {'label': 'U9149'}
# U18934 {'label': 'U18934'}
# U18948 {'label': 'U18948'}
# U4600 {'label': 'U4600'}
# U4638 {'label': 'U4638'}
# U7379 {'label': 'U7379'}
# U7192 {'label': 'U7192'}
# U15289 {'label': 'U15289'}
# U14005 {'label': 'U14005'}
# U24165 {'label': 'U24165'}
# U27553 {'label': 'U27553'}
# U14015 {'label': 'U14015'}
# U15329 {'label': 'U15329'}
# U24080 {'label': 'U24080'}
# U1073 {'label': 'U1073'}
# U18981 {'label': 'U18981'}
# U19856 {'label': 'U19856'}
# U4456 {'label': 'U4456'}
# U4012 {'label': 'U4012'}
# U3958 {'label': 'U3958'}
# U14117 {'label': 'U14117'}
# U24046 {'label': 'U24046'}
# U3954 {'label': 'U3954'}
# U7285 {'label': 'U7285'}
# U11564 {'label': 'U11564'}
# U7087 {'label': 'U7087'}
# U15173 {'label': 'U15173'}
# U7380 {'label': 'U7380'}
# U15318 {'label': 'U15318'}
# U7226 {'label': 'U7226'}
# U27460 {'label': 'U27460'}
# U7213 {'label': 'U7213'}
# U27711 {'label': 'U27711'}
# U11558 {'label': 'U11558'}
# U2625 {'label': 'U2625'}
# U11609 {'label': 'U11609'}
# U25634 {'label': 'U25634'}
# U7104 {'label': 'U7104'}
# U14575 {'label': 'U14575'}
# U18954 {'label': 'U18954'}
# U7279 {'label': 'U7279'}
# U3971 {'label': 'U3971'}
# U4625 {'label': 'U4625'}
# U1045 {'label': 'U1045'}
# U16132 {'label': 'U16132'}
# U27971 {'label': 'U27971'}
# U7151 {'label': 'U7151'}
# U7153 {'label': 'U7153'}
# U8086 {'label': 'U8086'}
# U7390 {'label': 'U7390'}
# U27661 {'label': 'U27661'}
# U8018 {'label': 'U8018'}
# U27752 {'label': 'U27752'}
# U13993 {'label': 'U13993'}
# U22011 {'label': 'U22011'}
# U27758 {'label': 'U27758'}
# U18914 {'label': 'U18914'}
# U14057 {'label': 'U14057'}
# U9130 {'label': 'U9130'}
# U24254 {'label': 'U24254'}
# U14572 {'label': 'U14572'}
# U8710 {'label': 'U8710'}
# U9660 {'label': 'U9660'}
# U15501 {'label': 'U15501'}
# U9706 {'label': 'U9706'}
# U2136 {'label': 'U2136'}
# U22824 {'label': 'U22824'}
# U1259 {'label': 'U1259'}
# U22780 {'label': 'U22780'}
# U15325 {'label': 'U15325'}
# U22825 {'label': 'U22825'}
# U10051 {'label': 'U10051'}
# U19842 {'label': 'U19842'}
# U27657 {'label': 'U27657'}
# U15177 {'label': 'U15177'}
# U11590 {'label': 'U11590'}
# U1220 {'label': 'U1220'}
# U4607 {'label': 'U4607'}
# U19913 {'label': 'U19913'}
# U1108 {'label': 'U1108'}
# U1068 {'label': 'U1068'}
# U14555 {'label': 'U14555'}
# U9154 {'label': 'U9154'}
# U8004 {'label': 'U8004'}
# U27676 {'label': 'U27676'}
# U14029 {'label': 'U14029'}
# U24062 {'label': 'U24062'}
# U24077 {'label': 'U24077'}
# U1252 {'label': 'U1252'}
# U27636 {'label': 'U27636'}
# U7967 {'label': 'U7967'}
# U27463 {'label': 'U27463'}
# U15168 {'label': 'U15168'}
# U27588 {'label': 'U27588'}
# U13988 {'label': 'U13988'}
# U14665 {'label': 'U14665'}
# U18943 {'label': 'U18943'}
# U27614 {'label': 'U27614'}
# U24117 {'label': 'U24117'}
# U1136 {'label': 'U1136'}
# U8699 {'label': 'U8699'}
# U7194 {'label': 'U7194'}
# U15321 {'label': 'U15321'}
# U27617 {'label': 'U27617'}
# U24128 {'label': 'U24128'}
# U22055 {'label': 'U22055'}
# U24205 {'label': 'U24205'}
# U7227 {'label': 'U7227'}
# U2723 {'label': 'U2723'}
# U4613 {'label': 'U4613'}
# U8054 {'label': 'U8054'}
# U7117 {'label': 'U7117'}
# U7307 {'label': 'U7307'}
# U7077 {'label': 'U7077'}
# U10631 {'label': 'U10631'}
# U18545 {'label': 'U18545'}
# U15193 {'label': 'U15193'}
# U18588 {'label': 'U18588'}
# U18539 {'label': 'U18539'}
# U27541 {'label': 'U27541'}
# U9655 {'label': 'U9655'}
# U25622 {'label': 'U25622'}
# U1196 {'label': 'U1196'}
# U22019 {'label': 'U22019'}
# U14490 {'label': 'U14490'}
# U4681 {'label': 'U4681'}
# U1072 {'label': 'U1072'}
# U22752 {'label': 'U22752'}
# U15466 {'label': 'U15466'}
# U24071 {'label': 'U24071'}
# U13995 {'label': 'U13995'}
# U27604 {'label': 'U27604'}
# U27756 {'label': 'U27756'}
# U16128 {'label': 'U16128'}
# U9657 {'label': 'U9657'}
# U7108 {'label': 'U7108'}
# U8091 {'label': 'U8091'}
# U13969 {'label': 'U13969'}
# U16134 {'label': 'U16134'}
# U21985 {'label': 'U21985'}
# U22828 {'label': 'U22828'}
# U6026 {'label': 'U6026'}
# U5982 {'label': 'U5982'}
# U14109 {'label': 'U14109'}
# U15174 {'label': 'U15174'}
# U13961 {'label': 'U13961'}
# U15939 {'label': 'U15939'}
# U18543 {'label': 'U18543'}
# U15932 {'label': 'U15932'}
# U9642 {'label': 'U9642'}
# U2688 {'label': 'U2688'}
# U4655 {'label': 'U4655'}
# U11587 {'label': 'U11587'}
# U27748 {'label': 'U27748'}
# U14024 {'label': 'U14024'}
# U14088 {'label': 'U14088'}
# U27577 {'label': 'U27577'}
# U2696 {'label': 'U2696'}
# U14136 {'label': 'U14136'}
# U18518 {'label': 'U18518'}
# U27499 {'label': 'U27499'}
# U7237 {'label': 'U7237'}
# U7260 {'label': 'U7260'}
# U2683 {'label': 'U2683'}
# U2656 {'label': 'U2656'}
# U24239 {'label': 'U24239'}
# U21094 {'label': 'U21094'}
# U8096 {'label': 'U8096'}
# U14008 {'label': 'U14008'}
# U4689 {'label': 'U4689'}
# U14492 {'label': 'U14492'}
# U27518 {'label': 'U27518'}
# U27721 {'label': 'U27721'}
# U24173 {'label': 'U24173'}
# U1359 {'label': 'U1359'}
# U7283 {'label': 'U7283'}
# U27473 {'label': 'U27473'}
# U7195 {'label': 'U7195'}
# U22072 {'label': 'U22072'}
# U7244 {'label': 'U7244'}
# U27687 {'label': 'U27687'}
# U18975 {'label': 'U18975'}
# U7109 {'label': 'U7109'}
# U25645 {'label': 'U25645'}
# U7132 {'label': 'U7132'}
# U7056 {'label': 'U7056'}
# U22006 {'label': 'U22006'}
# U8003 {'label': 'U8003'}
# U9153 {'label': 'U9153'}
# U9689 {'label': 'U9689'}
# U2209 {'label': 'U2209'}
# U24084 {'label': 'U24084'}
# U7170 {'label': 'U7170'}
# U27279 {'label': 'U27279'}
# U2761 {'label': 'U2761'}
# U6021 {'label': 'U6021'}
# U13968 {'label': 'U13968'}
# U1283 {'label': 'U1283'}
# U7373 {'label': 'U7373'}
# U7272 {'label': 'U7272'}
# U1134 {'label': 'U1134'}
# U5996 {'label': 'U5996'}
# U22010 {'label': 'U22010'}
# U21998 {'label': 'U21998'}
# U26952 {'label': 'U26952'}
# U6000 {'label': 'U6000'}
# U1284 {'label': 'U1284'}
# U1175 {'label': 'U1175'}
# U13981 {'label': 'U13981'}
# U14477 {'label': 'U14477'}
# U24130 {'label': 'U24130'}
# U19858 {'label': 'U19858'}
# U15968 {'label': 'U15968'}
# U21464 {'label': 'U21464'}
# U15299 {'label': 'U15299'}
# U4488 {'label': 'U4488'}
# U1214 {'label': 'U1214'}
# U7113 {'label': 'U7113'}
# U16152 {'label': 'U16152'}
# U7906 {'label': 'U7906'}
# U4634 {'label': 'U4634'}
# U3983 {'label': 'U3983'}
# U6011 {'label': 'U6011'}
# U24091 {'label': 'U24091'}
# U24087 {'label': 'U24087'}
# U2753 {'label': 'U2753'}
# U14657 {'label': 'U14657'}
# U21835 {'label': 'U21835'}
# U25627 {'label': 'U25627'}
# U14096 {'label': 'U14096'}
# U12932 {'label': 'U12932'}
# U13066 {'label': 'U13066'}
# U22017 {'label': 'U22017'}
# U7095 {'label': 'U7095'}
# U16140 {'label': 'U16140'}
# U7030 {'label': 'U7030'}
# U1071 {'label': 'U1071'}
# U18932 {'label': 'U18932'}
# U9649 {'label': 'U9649'}
# U15935 {'label': 'U15935'}
# U13007 {'label': 'U13007'}
# U2684 {'label': 'U2684'}
# U24176 {'label': 'U24176'}
# U16177 {'label': 'U16177'}
# U7351 {'label': 'U7351'}
# U25605 {'label': 'U25605'}
# U27608 {'label': 'U27608'}
# U11820 {'label': 'U11820'}
# U24241 {'label': 'U24241'}
# U19884 {'label': 'U19884'}
# U7350 {'label': 'U7350'}
# U6013 {'label': 'U6013'}
# U18524 {'label': 'U18524'}
# U7049 {'label': 'U7049'}
# U8036 {'label': 'U8036'}
# U27456 {'label': 'U27456'}
# U14138 {'label': 'U14138'}
# U24139 {'label': 'U24139'}
# U8904 {'label': 'U8904'}
# U7035 {'label': 'U7035'}
# U16167 {'label': 'U16167'}
# U8048 {'label': 'U8048'}
# U22771 {'label': 'U22771'}
# U22759 {'label': 'U22759'}
# U15994 {'label': 'U15994'}
# U7188 {'label': 'U7188'}
# U14508 {'label': 'U14508'}
# U15341 {'label': 'U15341'}
# U3914 {'label': 'U3914'}
# U16115 {'label': 'U16115'}
# U7202 {'label': 'U7202'}
# U3919 {'label': 'U3919'}
# U4461 {'label': 'U4461'}
# U7138 {'label': 'U7138'}
# U4574 {'label': 'U4574'}
# U3899 {'label': 'U3899'}
# U7167 {'label': 'U7167'}
# U15350 {'label': 'U15350'}
# U7304 {'label': 'U7304'}
# U15917 {'label': 'U15917'}
# U25625 {'label': 'U25625'}
# U2153 {'label': 'U2153'}
# U8080 {'label': 'U8080'}
# U27634 {'label': 'U27634'}
# U22843 {'label': 'U22843'}
# U27507 {'label': 'U27507'}
# U4517 {'label': 'U4517'}
# U25633 {'label': 'U25633'}
# U2677 {'label': 'U2677'}
# U27779 {'label': 'U27779'}
# U8298 {'label': 'U8298'}
# U7174 {'label': 'U7174'}
# U19874 {'label': 'U19874'}
# U22785 {'label': 'U22785'}
# U27649 {'label': 'U27649'}
# U7299 {'label': 'U7299'}
# U24113 {'label': 'U24113'}
# U1178 {'label': 'U1178'}
# U4676 {'label': 'U4676'}
# U3955 {'label': 'U3955'}
# U4489 {'label': 'U4489'}
# U15335 {'label': 'U15335'}
# U15296 {'label': 'U15296'}
# U27785 {'label': 'U27785'}
# U2691 {'label': 'U2691'}
# U14542 {'label': 'U14542'}
# U16089 {'label': 'U16089'}
# U14124 {'label': 'U14124'}
# U22051 {'label': 'U22051'}
# U14072 {'label': 'U14072'}
# U27471 {'label': 'U27471'}
# U27746 {'label': 'U27746'}
# U8076 {'label': 'U8076'}
# U7239 {'label': 'U7239'}
# U2750 {'label': 'U2750'}
# U22803 {'label': 'U22803'}
# U24054 {'label': 'U24054'}
# U10062 {'label': 'U10062'}
# U15308 {'label': 'U15308'}
# U4644 {'label': 'U4644'}
# U19896 {'label': 'U19896'}
# U27753 {'label': 'U27753'}
# U15974 {'label': 'U15974'}
# U14577 {'label': 'U14577'}
# U4647 {'label': 'U4647'}
# U14101 {'label': 'U14101'}
# U9138 {'label': 'U9138'}
# U24231 {'label': 'U24231'}
# U18560 {'label': 'U18560'}
# U4455 {'label': 'U4455'}
# U24082 {'label': 'U24082'}
# U22068 {'label': 'U22068'}
# U7987 {'label': 'U7987'}
# U22041 {'label': 'U22041'}
# U27726 {'label': 'U27726'}
# U9724 {'label': 'U9724'}
# U1104 {'label': 'U1104'}
# U8106 {'label': 'U8106'}
# U24171 {'label': 'U24171'}
# U2108 {'label': 'U2108'}
# U1174 {'label': 'U1174'}
# U14668 {'label': 'U14668'}
# U16137 {'label': 'U16137'}
# U2631 {'label': 'U2631'}
# U24218 {'label': 'U24218'}
# U9709 {'label': 'U9709'}
# U8030 {'label': 'U8030'}
# U3947 {'label': 'U3947'}
# U6025 {'label': 'U6025'}
# U10068 {'label': 'U10068'}
# U15349 {'label': 'U15349'}
# U2622 {'label': 'U2622'}
# U15267 {'label': 'U15267'}
# U14532 {'label': 'U14532'}
# U27691 {'label': 'U27691'}
# U1282 {'label': 'U1282'}
# U16197 {'label': 'U16197'}
# U22086 {'label': 'U22086'}
# U8909 {'label': 'U8909'}
# U24263 {'label': 'U24263'}
# U14499 {'label': 'U14499'}
# U27792 {'label': 'U27792'}
# U28776 {'label': 'U28776'}
# U2627 {'label': 'U2627'}
# U3909 {'label': 'U3909'}
# U16101 {'label': 'U16101'}
# U21443 {'label': 'U21443'}
# U8088 {'label': 'U8088'}
# U4661 {'label': 'U4661'}
# U27698 {'label': 'U27698'}
# U2650 {'label': 'U2650'}
# U14119 {'label': 'U14119'}
# U7270 {'label': 'U7270'}
# U22799 {'label': 'U22799'}
# U15307 {'label': 'U15307'}
# U27801 {'label': 'U27801'}
# U6001 {'label': 'U6001'}
# U7990 {'label': 'U7990'}
# U22819 {'label': 'U22819'}
# U9665 {'label': 'U9665'}
# U5981 {'label': 'U5981'}
# U8059 {'label': 'U8059'}
# U1199 {'label': 'U1199'}
# U15359 {'label': 'U15359'}
# U15934 {'label': 'U15934'}
# U22747 {'label': 'U22747'}
# U1089 {'label': 'U1089'}
# U24092 {'label': 'U24092'}
# U15611 {'label': 'U15611'}
# U5983 {'label': 'U5983'}
# U7917 {'label': 'U7917'}
# U18916 {'label': 'U18916'}
# U14500 {'label': 'U14500'}
# U25559 {'label': 'U25559'}
# U7349 {'label': 'U7349'}
# U3894 {'label': 'U3894'}
# U27642 {'label': 'U27642'}
# U4641 {'label': 'U4641'}
# U9122 {'label': 'U9122'}
# U16204 {'label': 'U16204'}
# U27772 {'label': 'U27772'}
# U3918 {'label': 'U3918'}
# U24064 {'label': 'U24064'}
# U21995 {'label': 'U21995'}
# U9128 {'label': 'U9128'}
# U9694 {'label': 'U9694'}
# U15928 {'label': 'U15928'}
# U25641 {'label': 'U25641'}
# U15334 {'label': 'U15334'}
# U1380 {'label': 'U1380'}
# U14043 {'label': 'U14043'}
# U7159 {'label': 'U7159'}
# U9667 {'label': 'U9667'}
# U15190 {'label': 'U15190'}
# U11597 {'label': 'U11597'}
# U27742 {'label': 'U27742'}
# U22838 {'label': 'U22838'}
# U8113 {'label': 'U8113'}
# U7317 {'label': 'U7317'}
# U4693 {'label': 'U4693'}
# U15317 {'label': 'U15317'}
# U27600 {'label': 'U27600'}
# U2724 {'label': 'U2724'}
# U7972 {'label': 'U7972'}
# U8104 {'label': 'U8104'}
# U22836 {'label': 'U22836'}
# U16174 {'label': 'U16174'}
# U27525 {'label': 'U27525'}
# U18549 {'label': 'U18549'}
# U1238 {'label': 'U1238'}
# U7909 {'label': 'U7909'}
# U14113 {'label': 'U14113'}
# U27515 {'label': 'U27515'}
# U11828 {'label': 'U11828'}
# U16216 {'label': 'U16216'}
# U14125 {'label': 'U14125'}
# U7114 {'label': 'U7114'}
# U15297 {'label': 'U15297'}
# U7234 {'label': 'U7234'}
# U7137 {'label': 'U7137'}
# U19831 {'label': 'U19831'}
# U22030 {'label': 'U22030'}
# U15316 {'label': 'U15316'}
# U24045 {'label': 'U24045'}
# U4628 {'label': 'U4628'}
# U10618 {'label': 'U10618'}
# U4633 {'label': 'U4633'}
# U27663 {'label': 'U27663'}
# U27618 {'label': 'U27618'}
# U13959 {'label': 'U13959'}
# U27532 {'label': 'U27532'}
# U24550 {'label': 'U24550'}
# U9141 {'label': 'U9141'}
# U24198 {'label': 'U24198'}
# U7096 {'label': 'U7096'}
# U15269 {'label': 'U15269'}
# U8049 {'label': 'U8049'}
# U7315 {'label': 'U7315'}
# U1331 {'label': 'U1331'}
# U1141 {'label': 'U1141'}
# U27692 {'label': 'U27692'}
# U12957 {'label': 'U12957'}
# U28774 {'label': 'U28774'}
# U16141 {'label': 'U16141'}
# U7220 {'label': 'U7220'}
# U25594 {'label': 'U25594'}
# U27763 {'label': 'U27763'}
# U15311 {'label': 'U15311'}
# U7092 {'label': 'U7092'}
# U1147 {'label': 'U1147'}
# U15944 {'label': 'U15944'}
# U22858 {'label': 'U22858'}
# U11817 {'label': 'U11817'}
# U7347 {'label': 'U7347'}
# U14121 {'label': 'U14121'}
# U27622 {'label': 'U27622'}
# U16179 {'label': 'U16179'}
# U7105 {'label': 'U7105'}
# U16127 {'label': 'U16127'}
# U22865 {'label': 'U22865'}
# U18562 {'label': 'U18562'}
# U4457 {'label': 'U4457'}
# U15336 {'label': 'U15336'}
# U7294 {'label': 'U7294'}
# U4562 {'label': 'U4562'}
# U7295 {'label': 'U7295'}
# U7338 {'label': 'U7338'}
# U4630 {'label': 'U4630'}
# U5980 {'label': 'U5980'}
# U3939 {'label': 'U3939'}
# U18973 {'label': 'U18973'}
# U7080 {'label': 'U7080'}
# U22022 {'label': 'U22022'}
# U4688 {'label': 'U4688'}
# U24100 {'label': 'U24100'}
# U14068 {'label': 'U14068'}
# U7288 {'label': 'U7288'}
# U22088 {'label': 'U22088'}
# U10059 {'label': 'U10059'}
# U27791 {'label': 'U27791'}
# U9630 {'label': 'U9630'}
# U4652 {'label': 'U4652'}
# U18983 {'label': 'U18983'}
# U8900 {'label': 'U8900'}
# U18965 {'label': 'U18965'}
# U24085 {'label': 'U24085'}
# U7326 {'label': 'U7326'}
# U2746 {'label': 'U2746'}
# U8068 {'label': 'U8068'}
# U18516 {'label': 'U18516'}
# U7180 {'label': 'U7180'}
# U13032 {'label': 'U13032'}
# U27648 {'label': 'U27648'}
# U2140 {'label': 'U2140'}
# U11823 {'label': 'U11823'}
# U9680 {'label': 'U9680'}
# U24189 {'label': 'U24189'}
# U22854 {'label': 'U22854'}
# U4680 {'label': 'U4680'}
# U27635 {'label': 'U27635'}
# U21838 {'label': 'U21838'}
# U7203 {'label': 'U7203'}
# U2653 {'label': 'U2653'}
# U22037 {'label': 'U22037'}
# U25618 {'label': 'U25618'}
# U8090 {'label': 'U8090'}
# U7983 {'label': 'U7983'}
# U7198 {'label': 'U7198'}
# U10050 {'label': 'U10050'}
# U1226 {'label': 'U1226'}
# U15957 {'label': 'U15957'}
# U27516 {'label': 'U27516'}
# U18915 {'label': 'U18915'}
# U24177 {'label': 'U24177'}
# U15919 {'label': 'U15919'}
# U4025 {'label': 'U4025'}
# U2680 {'label': 'U2680'}
# U18962 {'label': 'U18962'}
# U4467 {'label': 'U4467'}
# U15333 {'label': 'U15333'}
# U22059 {'label': 'U22059'}
# U1047 {'label': 'U1047'}
# U6028 {'label': 'U6028'}
# U7173 {'label': 'U7173'}
# U7176 {'label': 'U7176'}
# U24247 {'label': 'U24247'}
# U12020 {'label': 'U12020'}
# U27569 {'label': 'U27569'}
# U27738 {'label': 'U27738'}
# U27674 {'label': 'U27674'}
# U4610 {'label': 'U4610'}
# U25636 {'label': 'U25636'}
# U1254 {'label': 'U1254'}
# U1303 {'label': 'U1303'}
# U7253 {'label': 'U7253'}
# U24260 {'label': 'U24260'}
# U24158 {'label': 'U24158'}
# U27941 {'label': 'U27941'}
# U9627 {'label': 'U9627'}
# U8721 {'label': 'U8721'}
# U15344 {'label': 'U15344'}
# U27707 {'label': 'U27707'}
# U7033 {'label': 'U7033'}
# U18938 {'label': 'U18938'}
# U7090 {'label': 'U7090'}
# U2663 {'label': 'U2663'}
# U27542 {'label': 'U27542'}
# U7370 {'label': 'U7370'}
# U15287 {'label': 'U15287'}
# U27332 {'label': 'U27332'}
# U15368 {'label': 'U15368'}
# U11827 {'label': 'U11827'}
# U27508 {'label': 'U27508'}
# U21970 {'label': 'U21970'}
# U4439 {'label': 'U4439'}
# U27289 {'label': 'U27289'}
# U14479 {'label': 'U14479'}
# U24184 {'label': 'U24184'}
# U5977 {'label': 'U5977'}
# U14131 {'label': 'U14131'}
# U8050 {'label': 'U8050'}
# U27287 {'label': 'U27287'}
# U13954 {'label': 'U13954'}
# U24142 {'label': 'U24142'}
# U18597 {'label': 'U18597'}
# U13029 {'label': 'U13029'}
# U3989 {'label': 'U3989'}
# U18928 {'label': 'U18928'}
# U8702 {'label': 'U8702'}
# U14566 {'label': 'U14566'}
# U8100 {'label': 'U8100'}
# U1055 {'label': 'U1055'}
# U4542 {'label': 'U4542'}
# U4568 {'label': 'U4568'}
# U22074 {'label': 'U22074'}
# U22045 {'label': 'U22045'}
# U27737 {'label': 'U27737'}
# U18555 {'label': 'U18555'}
# U8741 {'label': 'U8741'}
# U18942 {'label': 'U18942'}
# U24238 {'label': 'U24238'}
# U8768 {'label': 'U8768'}
# U8066 {'label': 'U8066'}
# U11566 {'label': 'U11566'}
# U16084 {'label': 'U16084'}
# U14526 {'label': 'U14526'}
# U14531 {'label': 'U14531'}
# U22817 {'label': 'U22817'}
# U16078 {'label': 'U16078'}
# U7989 {'label': 'U7989'}
# U8098 {'label': 'U8098'}
# U27602 {'label': 'U27602'}
# U19886 {'label': 'U19886'}
# U9710 {'label': 'U9710'}
# U24504 {'label': 'U24504'}
# U9126 {'label': 'U9126'}
# U15949 {'label': 'U15949'}
# U18939 {'label': 'U18939'}
# U15294 {'label': 'U15294'}
# U14547 {'label': 'U14547'}
# U25610 {'label': 'U25610'}
# U15482 {'label': 'U15482'}
# U27475 {'label': 'U27475'}
# U27704 {'label': 'U27704'}
# U22775 {'label': 'U22775'}
# U10637 {'label': 'U10637'}
# U4000 {'label': 'U4000'}
# U22003 {'label': 'U22003'}
# U19848 {'label': 'U19848'}
# U14537 {'label': 'U14537'}
# U16153 {'label': 'U16153'}
# U16219 {'label': 'U16219'}
# U22044 {'label': 'U22044'}
# U27494 {'label': 'U27494'}
# U8111 {'label': 'U8111'}
# U24132 {'label': 'U24132'}
# U1044 {'label': 'U1044'}
# U11563 {'label': 'U11563'}
# U27575 {'label': 'U27575'}
# U11580 {'label': 'U11580'}
# U8269 {'label': 'U8269'}
# U7024 {'label': 'U7024'}
# U27627 {'label': 'U27627'}
# U19873 {'label': 'U19873'}
# U2744 {'label': 'U2744'}
# U7262 {'label': 'U7262'}
# U4485 {'label': 'U4485'}
# U3944 {'label': 'U3944'}
# U7986 {'label': 'U7986'}
# U14496 {'label': 'U14496'}
# U4563 {'label': 'U4563'}
# U2734 {'label': 'U2734'}
# U14080 {'label': 'U14080'}
# U16091 {'label': 'U16091'}
# U14529 {'label': 'U14529'}
# U18964 {'label': 'U18964'}
# U4685 {'label': 'U4685'}
# U15950 {'label': 'U15950'}
# U18570 {'label': 'U18570'}
# U22002 {'label': 'U22002'}
# U4452 {'label': 'U4452'}
# U4010 {'label': 'U4010'}
# U22861 {'label': 'U22861'}
# U11559 {'label': 'U11559'}
# U18593 {'label': 'U18593'}
# U18949 {'label': 'U18949'}
# U24154 {'label': 'U24154'}
# U27603 {'label': 'U27603'}
# U14557 {'label': 'U14557'}
# U14150 {'label': 'U14150'}
# U4448 {'label': 'U4448'}
# U7281 {'label': 'U7281'}
# U21848 {'label': 'U21848'}
# U25563 {'label': 'U25563'}
# U21827 {'label': 'U21827'}
# U7256 {'label': 'U7256'}
# U15342 {'label': 'U15342'}
# U18557 {'label': 'U18557'}
# U24183 {'label': 'U24183'}
# U7141 {'label': 'U7141'}
# U3922 {'label': 'U3922'}
# U16085 {'label': 'U16085'}
# U27656 {'label': 'U27656'}
# U1379 {'label': 'U1379'}
# U18586 {'label': 'U18586'}
# U22076 {'label': 'U22076'}
# U7082 {'label': 'U7082'}
# U7074 {'label': 'U7074'}
# U8279 {'label': 'U8279'}
# U4619 {'label': 'U4619'}
# U15286 {'label': 'U15286'}
# U4606 {'label': 'U4606'}
# U21969 {'label': 'U21969'}
# U4005 {'label': 'U4005'}
# U8670 {'label': 'U8670'}
# U14123 {'label': 'U14123'}
# U27613 {'label': 'U27613'}
# U7377 {'label': 'U7377'}
# U27557 {'label': 'U27557'}
# U22073 {'label': 'U22073'}
# U24179 {'label': 'U24179'}
# U9711 {'label': 'U9711'}
# U22849 {'label': 'U22849'}
# U9679 {'label': 'U9679'}
# U22753 {'label': 'U22753'}
# U1119 {'label': 'U1119'}
# U24224 {'label': 'U24224'}
# U12970 {'label': 'U12970'}
# U7402 {'label': 'U7402'}
# U7156 {'label': 'U7156'}
# U16098 {'label': 'U16098'}
# U28772 {'label': 'U28772'}
# U7091 {'label': 'U7091'}
# U27761 {'label': 'U27761'}
# U27549 {'label': 'U27549'}
# U14007 {'label': 'U14007'}
# U7319 {'label': 'U7319'}
# U8795 {'label': 'U8795'}
# U4635 {'label': 'U4635'}
# U14519 {'label': 'U14519'}
# U8110 {'label': 'U8110'}
# U22820 {'label': 'U22820'}
# U15197 {'label': 'U15197'}
# U27777 {'label': 'U27777'}
# U27784 {'label': 'U27784'}
# U10607 {'label': 'U10607'}
# U7189 {'label': 'U7189'}
# U27798 {'label': 'U27798'}
# U14564 {'label': 'U14564'}
# U14112 {'label': 'U14112'}
# U4586 {'label': 'U4586'}
# U8828 {'label': 'U8828'}
# U7199 {'label': 'U7199'}
# U18520 {'label': 'U18520'}

# %% [markdown]
# # Strategy 0 to fill the empty profiles = your baseline: naive method
#
# The assumption is that two connected nodes are likely to share the same attribute values. Here we choose the most frequently used attribute value among the neighbors.

# %%
naive_predicted_values={}

# %%
def naive_method(graph, empty, df):
    """   Predict the missing attribute with a simple but effective
    relational classifier. 
    
    The assumption is that two connected nodes are 
    likely to share the same attribute value. Here we chose the most frequently
    used attribute by the neighbors
    
    Parameters
    ----------
    graph : graph
       A networkx graph
    empty : list
       The nodes with empty attributes 
    df : pandas dataframe 
       Either location, employer or college dataframe. 

    Returns
    -------
    predicted_values : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node (from empty), value is a list of attribute values. Here 
       only 1 value in the list.
     """
    predicted_values={}
    for n in empty:
        nbrs_attr_values=[] 
        for nbr in graph.neighbors(n):
            # attribute values for the node nbr
            attr = df_e.loc[df_e.name == nbr ,'employer'].values
            
            if attr.size > 0: #array not empty
                for val in attr:
                    nbrs_attr_values.append(val)
        predicted_values[n]=[]
        if nbrs_attr_values: # non empty list
            # count the number of occurrence each value and returns a dict
            cpt=Counter(nbrs_attr_values)
            
            # take the most represented attribute value among neighbors
            a,nb_occurrence=max(cpt.items(), key=lambda t: t[1])
            #print(a,nb_occurrence)
            predicted_values[n].append(a)
    return predicted_values

# %%
naive_predicted_values = naive_method(G, empty, df_e)

# %%
print(naive_predicted_values)
# Out:
# {'U27476': ['google'], 'U4665': [], 'U14078': ['university of illinois at urbana-champaign'], 'U9628': ['state farm'], 'U9721': ['champaign-urbana community fabrication laboratory'], 'U27759': [], 'U24095': ['stanford university'], 'U4249': ['copper creek church'], 'U27776': [], 'U27708': [], 'U15284': ['university of illinois at urbana-champaign'], 'U24549': [], 'U18514': ['ultimate software'], 'U15946': ['boston consulting group'], 'U25630': ['measured progress'], 'U25632': ['measured progress'], 'U22031': [], 'U7912': ['university of illinois at urbana-champaign'], 'U22018': [], 'U18925': ['university of illinois at urbana-champaign'], 'U7136': [], 'U3927': [], 'U1381': ['ets'], 'U22087': [], 'U27804': [], 'U7355': ['siemens healthcare'], 'U14024': ['university of illinois at urbana-champaign'], 'U27679': [], 'U27464': [], 'U24259': [], 'U18564': [], 'U11575': ["noah's ark lab huawei technologies co. ltd."], 'U14507': ['merge llc'], 'U27477': ['baidu inc.'], 'U24143': [], 'U22015': [], 'U27498': [], 'U9663': ['san diego gas &amp; electric'], 'U14520': ['vineyard church'], 'U8051': [], 'U27300': ['spot trading llc'], 'U18948': ['university of illinois at urbana-champaign'], 'U4600': ['google'], 'U14005': ['university of illinois at urbana-champaign'], 'U24165': [], 'U27553': [], 'U1073': ['ets'], 'U19856': ['clorox company'], 'U4456': ['university of illinois at urbana-champaign'], 'U4012': ["noah's ark lab huawei technologies co. ltd."], 'U3954': ['vertica systems an hp company'], 'U7087': [], 'U15173': [], 'U7380': [], 'U15318': ['kona software lab ltd. (r&amp;d center of konai s. korea))'], 'U7226': [], 'U27460': ['yelp.com'], 'U27711': [], 'U11558': ['vertica systems an hp company'], 'U2625': ['university of texas at austin'], 'U25634': ['measured progress'], 'U7104': [], 'U14575': ['express employment professionals'], 'U3971': ['microsoft'], 'U4625': [], 'U27971': ['illinois institute of technology'], 'U7153': [], 'U8086': [], 'U7390': ['cancer prevention and research institute of texas'], 'U8018': [], 'U27752': [], 'U13993': ['microsoft'], 'U18914': ['university of illinois at urbana-champaign'], 'U14057': [], 'U14572': [], 'U8710': ['university of illinois at urbana-champaign'], 'U15501': [], 'U9706': ['university of illinois at urbana-champaign'], 'U22824': ['university of illinois at urbana-champaign'], 'U22780': ['university of illinois at urbana-champaign'], 'U15325': [], 'U22825': ['bhabha atomic research center'], 'U27657': ['university of texas at austin'], 'U4607': ['pricewaterhousecoopers'], 'U19913': ['university of illinois at urbana-champaign'], 'U14555': [], 'U9154': ['office of community college research and leadership'], 'U8004': [], 'U27676': [], 'U14029': ['university of illinois at urbana-champaign'], 'U24077': ['whova'], 'U7967': [], 'U27463': [], 'U27588': ['yelp.com'], 'U18943': ['university of illinois at urbana-champaign'], 'U7194': [], 'U24152': ['shega'], 'U22055': [], 'U24205': [], 'U7227': [], 'U2723': [], 'U4613': ['university of illinois at urbana-champaign'], 'U8054': [], 'U7307': [], 'U7077': [], 'U18545': [], 'U15193': ['niksun'], 'U18539': ['systems research group university of illinois at urbana-champaign'], 'U25622': ['measured progress'], 'U14490': ['vineyard church'], 'U4681': [], 'U1072': ['measured progress'], 'U22752': ['university of illinois at urbana-champaign'], 'U15466': [], 'U24071': ['apple'], 'U27604': [], 'U27756': [], 'U16128': ['pwc'], 'U7108': [], 'U8091': [], 'U13969': ['university of illinois at urbana-champaign'], 'U16134': ['cummins inc.'], 'U21985': [], 'U5982': ['merge llc'], 'U14109': ['university of illinois at urbana-champaign'], 'U15174': [], 'U15939': ['brookhaven national laboratory'], 'U18543': [], 'U9642': ['san diego gas &amp; electric'], 'U2688': [], 'U4655': [], 'U11587': [], 'U27748': [], 'U9694': [], 'U14088': ['university of illinois at urbana-champaign'], 'U27577': [], 'U2696': [], 'U18518': ['ultimate software'], 'U27499': [], 'U7237': [], 'U726 ...

# %% [markdown]
# # Strategy 1 to fill the empty profiles

# %%
# use the information of neighbor's neighbors
def method1(graph, empty, df):
    predicted_values={}
    for n in empty:
        nbrs_attr_values={}
        
        for nbr in graph.neighbors(n):
            # attribute values for the node nbr
            attr = df_e.loc[df_e.name == nbr ,'employer'].values
            if attr.size > 0: #array not empty
                for val in attr:
                    if val not in nbrs_attr_values:
                        nbrs_attr_values[val] = 1
                    else:
                        nbrs_attr_values[val] += 1
            
            for nnbr in graph.neighbors(nbr):
                attr = df_e.loc[df_e.name == nnbr ,'employer'].values
                
                if attr.size > 0: #array not empty
                    for val in attr:
                        if val in nbrs_attr_values:
                            nbrs_attr_values[val] += 0.5
                            #print(nbrs_attr_values)
                                 
        predicted_values[n]=[]
        if nbrs_attr_values: # non empty list
            # count the number of occurrence each value and returns a dict
            cpt=Counter(nbrs_attr_values)
            
            # take the most represented attribute value among neighbors
            a,nb_occurrence=max(cpt.items(), key=lambda t: t[1])
            #print(nb_occurrence)
            predicted_values[n].append(a)
    return predicted_values

# %%
predicted_values1 = method1(G, empty, df_e)

# %% [markdown]
# # Strategy 2 to fill the empty profiles

# %%
def method2(graph, empty, df):
    predicted_values={}
    for n in empty:
        nbrs_attr_values={}
        
        for nbr in graph.neighbors(n):
            # attribute values for the node nbr
            attr = df_e.loc[df_e.name == nbr ,'employer'].values
            if attr.size > 0: #array not empty
                for val in attr:
                    if val not in nbrs_attr_values:
                        nbrs_attr_values[val] = 1
                    else:
                        nbrs_attr_values[val] += 1
            
            for nnbr in graph.neighbors(nbr):
                attr = df_e.loc[df_e.name == nnbr ,'employer'].values
                
                if attr.size > 0: #array not empty
                    for val in attr:
                        if val in nbrs_attr_values:
                            nbrs_attr_values[val] += 0.5
                            #print(nbrs_attr_values)
                        
        
            
                
        predicted_values[n]=[]
        if nbrs_attr_values: # non empty list
            # count the number of occurrence each value and returns a dict
            cpt=Counter(nbrs_attr_values)
            
            # take the most represented attribute value among neighbors
            L = sorted(cpt.items(),key=lambda item:item[1],reverse=True)[:2]
            #a,nb_occurrence=max(cpt.items(), key=lambda t: t[1])
            #print(nb_occurrence)
            a = []
            for l in L:
                a.append(l[0]) 
            predicted_values[n].append(a)
    return predicted_values

# %%
predicted_values2 = method2(G, empty, df_e)

# %% [markdown]
# # Strategy 3

# %%
def method3(graph, empty, df):

    predicted_values={}
    for n in empty:
        nbrs_attr_values=[] 
        for nbr in graph.neighbors(n):
            # attribute values for the node nbr
            attr = df_e.loc[df_e.name == nbr ,'employer'].values
            
            if attr.size > 0: #array not empty
                for val in attr:
                    nbrs_attr_values.append(val)
        predicted_values[n]=[]
        if nbrs_attr_values: # non empty list
            # count the number of occurrence each value and returns a dict
            cpt=Counter(nbrs_attr_values)
                       
            L = sorted(cpt.items(),key=lambda item:item[1],reverse=True)
            
            a = []
            for i,l in enumerate(L):
                print(l)
                while l[1] > 1:
                    a.append(l[0]) 
                    
            #print(a)
            predicted_values[n].append(a)
            
            
            
            
    return predicted_values

# %%
predicted_values3 = method3(G, empty, df_e)
# Out:
# ('google', 1)
# ('at&amp;t labs inc.', 1)
# ('university of michigan', 1)
# ('uc san diego', 1)
# ('cisco systems', 1)
# ('qad inc', 1)
# []
# ('university of illinois at urbana-champaign', 1)
# ('software competitiveness international', 1)
# ('wexgroup', 1)
# ('intered', 1)
# []
# ('state farm', 1)
# ('illinois business consulting', 1)
# ('argonne national laboratory', 1)
# ('san diego gas &amp; electric', 1)
# ('university of illinois at urbana-champaign', 1)
# ('technische universit&#xe4;t darmstadt', 1)
# ('kraft foods', 1)
# []
# ('champaign-urbana community fabrication laboratory', 1)
# ('manplan inc', 1)
# []
# ('stanford university', 1)
# []
# ('copper creek church', 1)
# ('cv lloyde', 1)
# ('sony biotechnology inc.', 1)
# ('merge llc', 1)
# ('merge partners inc', 1)
# ('vineyard church', 1)
# ('state farm insurance', 1)
# ('hearts at home', 1)
# ('shapemaster inc.', 1)
# ('vizion interactive', 1)
# ('search fanatics', 1)
# ('click2rank consulting llc', 1)
# ('seo by jt', 1)
# ('innovadex', 1)
# ('church of harvest', 1)
# ('t-mobile', 1)
# ('mercy &amp; truth medical missions', 1)
# ('security benefit', 1)
# ('elemental imaging', 1)
# ('command performance research', 1)
# ('killer works', 1)
# ('undisclosed', 1)
# ('actency', 1)
# ('abner guzman phd', 1)
# ('uiknow inc.', 1)
# ('electronic arts', 1)
# ('department of computer science university of illinois at urbana-champaign', 1)
# ('motorola', 1)
# ('mimosa accoustics', 1)
# ('gas technology institute', 1)
# ('baxter healthcare', 1)
# ('localytics', 1)
# []
# ('university of illinois at urbana-champaign', 2)

# %% [markdown]
# # Evaluation

# %%
df_e_truth = pd.read_csv('./challenge1/groundtruth/employer.csv', sep='\t', header='infer')
df_e_truth.head()
# Out:
#      name                           employer
# 0  U21998    illinois college advising corps
# 1  U21998                victoria amplifiers
# 2  U21998  university of illinois at chicago
# 3  U27476                                ibm
# 4  U27476                      nyse euronext

# %%
df_e_truth.loc[df_e_truth.name == 'U21998',df_e_truth.columns[1]].values
# Out:
# array(['illinois college advising corps', 'victoria amplifiers',
#        'university of illinois at chicago'], dtype=object)

# %%
def evaluation_accuracy(groundtruth, pred):
    """    Compute the accuracy of your model.

     The accuracy is the proportion of true results.

    Parameters
    ----------
    groundtruth : pandas dataframe 
       Either location, employer or college dataframe. 
    pred : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node, value is a list of attribute values. 

    Returns
    -------
    out : float
       Accuracy.
    """
    true_positive_prediction=0
    predicted=0
    for p_key, p_value in pred.items():
        attr = groundtruth.loc[groundtruth.name == p_key ,groundtruth.columns[1]].values
        # if prediction is empty, e.g. [], and so is the groundtruth
        # May happen, we count it as a true prediction
        if not p_value and attr.size == 0:
            true_positive_prediction+=1
            predicted+=1
        # counts the number of good prediction for node p_key
        # here len(p_value)=1 but we could have tried to predict more values
        # if p_value == [], we add 0
        true_positive_prediction += len([c for c in p_value if c in attr])
        predicted += len([c for c in p_value])
    return true_positive_prediction*100/predicted

# %%
result=evaluation_accuracy(df_e_truth, naive_predicted_values)
print("%f%% of the predictions are true" % result)
print("Very poor result!!! Try to do better!!!!")
# Out:
# 27.397260% of the predictions are true
# Very poor result!!! Try to do better!!!!

# %%
result=evaluation_accuracy(df_e_truth, predicted_values1)
print("%f%% of the predictions are true" % result)
print("Very poor result!!! Try to do better!!!!")
# Out:
# 32.534247% of the predictions are true
# Very poor result!!! Try to do better!!!!

# %%
result=evaluation_accuracy(df_e_truth, predicted_values2)
print("%f%% of the predictions are true" % result)
print("Very poor result!!! Try to do better!!!!")
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:31: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# 19.863014% of the predictions are true
# Very poor result!!! Try to do better!!!!

# %%
result=evaluation_accuracy(df_e_truth, predicted_values3)
print("%f%% of the predictions are true" % result)
print("Very poor result!!! Try to do better!!!!")
# Out:
# 27.397260% of the predictions are true
# Very poor result!!! Try to do better!!!!
